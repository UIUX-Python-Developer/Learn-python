# %%
print('Hello Imtiaj Howlader!', 'Welcom to Python Programming World.')
# Out:
# Hello Imtiaj Howlader! Welcom to Python Programming World.

# %%
test= 'Hello Imtiaj Howlader! Welcom to Python Programming World.'
print(test)
# Out:
# Hello Imtiaj Howlader! Welcom to Python Programming World.

# %%
print('test')
# Out:
# test

# %%
id(test)
# Out:
# 2487661805248

# %%
test1= ' Hello Python world'
print(test1)

print(' My sentence is,' + test1)
# Out:
#  Hello Python world
#  My sentence is, Hello Python world

# %%
id (test1)
# Out:
# 2487663605680

# %%
import sys
sys.getsizeof(test1)
# Out:
# 60

# %%
test_1 = 100
test_1
# Out:
# 100

# %%
Test_2=50
Test_2
# Out:
# 50

# %%
X,Y,Z = 10,100,190
Y,X,Z
# Out:
# (100, 10, 190)

# %%
X,Y,Z = 10,100,190
Z,X,Y
# Out:
# (190, 10, 100)

# %%
X,Y,Z = 10,100
Y,Z
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 X,Y,Z = 10,100
#       2 Y,Z
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x = 500 #global
def func1():
     print('My Num is:',x)
func1()
# Out:
# My Num is: 500

# %%
x = 500 #global
def func1():
     print('My Num is:',x)
func1()
print(x)
# Out:
# My Num is: 500
# 500

# %%
x = 700 #global

def func1():
    x = 500 #local
    print('My Num is:', x)

func1()
print('This Num is:', x)
# Out:
# My Num is: 500
# This Num is: 700

# %%
def func1():
    global x
    x = 500 #local
    print('My Num is:', x)

func1()
print('This Num is:', x)
# Out:
# My Num is: 500
# This Num is: 500

# %%
#String

# %%
data = 'Python Learning'

# %%
type(data)
# Out:
# str

# %%
imtiaj = 'learn python'

# %%
type(imtiaj)
# Out:
# str

# %%
 data = 'quatetion er vitore ja thake tai string'

# %%
type(data)
# Out:
# str

# %%
x = input()
y = input()
# Out:
#  20
#  13

# %%
x+y
# Out:
# '2013'

# %%
x = int(x)
y = int(y)

# %%
x+y
# Out:
# 33

# %%
type(y)
# Out:
# int

# %%
x = int(input('Enter or write your 1st Number'))
# Out:
# Enter or write your 1st Number 20

# %%
x
# Out:
# 20

# %%
y = int(input('Enter or write your 2nd Number'))
# Out:
# Enter or write your 1st Number 12.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 y = int(input('Enter or write your 1st Number'))
#
# ValueError: invalid literal for int() with base 10: '12.5'

# %%
y = int(input('Enter or write your 1st Number'))
# Out:
# Enter or write your 1st Number 12

# %%
y
# Out:
# 12

# %%
x+y
# Out:
# 32

# %%
x = int(input('Enter or write your 1st Number'))
# Out:
# Enter or write your 1st Number 20

# %%
y = float(input('Enter or write your 2nd Number'))
# Out:
# Enter or write your 2nd Number 2.5

# %%
x-y
# Out:
# 17.5

# %%
x*y
# Out:
# 50.0

# %%
x+y
# Out:
# 22.5

# %%
x = float(input('Enter or write your 1st Number'))
y = float(input('Enter or write your 2nd Number'))
# Out:
# Enter or write your 1st Number 30
# Enter or write your 2nd Number 20

# %%
x-y
# Out:
# 10.0

# %%
x = float(input('Enter or write your 1st Number'))
y = float(input('Enter or write your 2nd Number'))
# Out:
# Enter or write your 1st Number 30
# Enter or write your 2nd Number .07857

# %%
x+y
# Out:
# 30.07857

# %%
x*y
# Out:
# 2.3571

# %%
x-y
# Out:
# 29.92143

# %%
x = float(input('Enter or write your 1st Number'))
y = float(input('Enter or write your 2nd Number'))
# Out:
# Enter or write your 1st Number aburyhan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 x = float(input('Enter or write your 1st Number'))
#       2 y = float(input('Enter or write your 2nd Number'))
#
# ValueError: could not convert string to float: 'aburyhan'

# %%
x = float(input('Enter or write your 1st Number'))
y = float(input('Enter or write your 2nd Number'))
# Out:
# Enter or write your 1st Number 1.2
# Enter or write your 2nd Number 10.3

# %%
x+y
# Out:
# 11.5

# %%
type(x)
# Out:
# float

# %%
x= 'learn python'

# %%
type(x)
# Out:
# str

# %%
len(x)
# Out:
# 12

# %%
import sys
sys.getsizeof(x)
# Out:
# 53

# %%
x.count('python')
# Out:
# 1

# %%
x.count('learn
