# %%
data = 'learn python'
data.find('py')
# Out:
# 6

# %%
imtiaj = "UI/UX Designer"

# %%
imtiaj.find('sg')
# Out:
# -1

# %%
imtiaj.find("UX")
# Out:
# 3

# %%
imtiaj.find('si')
# Out:
# 8

# %%
imtiaj.find('i')
# Out:
# 9

# %%
imtiaj.find('gn',6, 4)
# Out:
# -1

# %%
imtiaj.find('gn',6, 14)
# Out:
# 10

# %%
imtiaj.find('er')
# Out:
# 12

# %%
imtiaj.find('r') #find value from string
# Out:
# 13

# %%
imtiaj.find('e')
# Out:
# 7

# %%
imtiaj.index('e')
# Out:
# 7

# %%
imtiaj.index('De') #find value from in string
# Out:
# 6

# %%
imtiaj.index('d',5,15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 imtiaj.index('d',5,15)
#
# NameError: name 'imtiaj' is not defined

# %%
imtiaj.lower() #convert all character into lower case
# Out:
# 'ui/ux designer'

# %%
imtiaj.upper() #convert all character into uper case
# Out:
# 'UI/UX DESIGNER'

# %%
imtiaj.capitalize() #convert only first character into uper case
# Out:
# 'Ui/ux designer'

# %%
imtiaj.swapcase()
# Out:
# 'ui/ux dESIGNER'

# %%
imtiaj.title() #convert only first character into uper case
# Out:
# 'Ui/Ux Designer'

# %%
imtiaj.islower()
# Out:
# False

# %%
imtiaj.isupper()
# Out:
# False

# %%
imtiaj.isdigit()
# Out:
# False

# %%
data= "2003"

# %%
data.isdigit()
# Out:
# True

# %%
data = "imtiaj 2003"

# %%
data.isdigit()
# Out:
# False

# %%
data.encode()
# Out:
# b'imtiaj 2003'

# %%
type(data.encode())
# Out:
# bytes

# %%
type(data.encode)
# Out:
# builtin_function_or_method

# %%
imtiaj
# Out:
# 'UI/UX Designer'

# %%
imtiaj.split()
# Out:
# ['UI/UX', 'Designer']

# %%
imtiaj.split()[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 imtiaj.split()[0]
#
# NameError: name 'imtiaj' is not defined

# %%
imtiaj.center(20)
# Out:
# '   UI/UX Designer   '

# %%
imtiaj.replace('UI/UX', 'Learen AI Engineer')
# Out:
# 'Learen AI Engineer Designer'

# %%
x=20
y=30
z=x*y

print('I have',z,'taka')
# Out:
# I have 600 taka

# %%
python= 'Imtiaj learn python'

# %%
python.index('py')
# Out:
# 13

# %%
python.index('e')
# Out:
# 8

# %%
python.index('e',3,6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 python.index('e',3,6)
#
# ValueError: substring not found

# %%
python.find('j')
# Out:
# 5

# %%
python.find('t',5,10)
# Out:
# -1

# %%
python.split()
# Out:
# ['Imtiaj', 'learn', 'python']

# %%
python.split()[0]
# Out:
# 'Imtiaj'

# %%
python.split()[2]
# Out:
# 'python'

# %%
python.center(50)
# Out:
# '               Imtiaj learn python                '

# %%
python.split()[2]
# Out:
# 'python'

# %%
python.split()[1]
# Out:
# 'learn'

# %%
python.replace('learn', 'AI learning in')
# Out:
# 'Imtiaj AI learning in python'

# %%
x=20
y=30
z=x*y

print('I have',z,'taka')
# Out:
# I have 600 taka

# %%
print('I have {} Doller'.format(z))
# Out:
# I have 600 Doller
