# %% [raw]
# #Numeric Data

# %%
x= 20 #int
y= 20.75 #float
z= 10+3j #complex #10 is real part and 3j is imaginary part

# %%
type(z)
# Out:
# complex

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
isinstance(z,complex)
# Out:
# True

# %%
isinstance(x,float)
# Out:
# False

# %%
isinstance(x,int)
# Out:
# True

# %%
isinstance(y,float)
# Out:
# True

# %%
isinstance(y,int)
# Out:
# False

# %%
#int to float
n= float(x) #n=float

# %%
n
# Out:
# 20.0

# %%
type(n)
# Out:
# float

# %%
#float to int
a=int(y) #a=int

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
#int to complex
A= complex(x) #A=complex

# %%
A
# Out:
# (20+0j)

# %%
#complex to int
b= int(A) #complex to int or floar is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 #complex to int
# ----> 2 b= int(A) #complex to int or floar is not possible
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
#complex to float
c= float(A) #complex to int or floar is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 #complex to float
# ----> 2 c= float(A) #complex to int or floar is not possible
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
data= complex(input())

# %%
data=complex(input('write:'))
# Out:
# write: 1

# %%
data
# Out:
# (1+0j)

# %%
type(data)
# Out:
# complex

# %%
data1=int(input('write inte:'))
# Out:
# write inte: 10

# %%
type(data1)
# Out:
# int

# %%
data2=float(input('write float number:'))
# Out:
# write float number: 10

# %%
type(data2)
# Out:
# float

# %%
data3=int(input('write number')) #flas code
# Out:
# write number 10.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data3=int(input('write number'))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
type(data3) #flas data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 type(data3) #flas data
#
# NameError: name 'data3' is not defined

# %% [markdown]
# Boolean

# %%
X= True  #right data type 
y= False

# %%
X= true
y= false #vul type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 X= true
#       2 y= false #vul type
#
# NameError: name 'true' is not defined
